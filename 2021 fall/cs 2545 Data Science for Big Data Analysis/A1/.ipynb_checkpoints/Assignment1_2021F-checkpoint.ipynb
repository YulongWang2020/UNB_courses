# %% [markdown]
# # Assignment 1
#
# ### CS2545 - Data Science ###
# ### Fall, 2021 ###
# ### UNB, Fredericton ###
#
# Please complete the following and submit this notebook (filename: Assignment1-**lastname**-**firstname**.ipynb) to D2L by 5 pm, November 5.
# </br>
# </br>
# </br>

# %% [markdown]
# **Q1.0** Download the *countries.csv*  and *world_gdp_2019.csv* files from D2L in the current folder. Load them into two dataframes and show first 5 rows.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Load countries.csv
countries = pd.read_csv('countries.csv',sep=';')
countries.head()
# Out:
#           Country  Population     Area Currency
# 0     Afghanistan    32564342   652230  Afghani
# 1           Egypt    88487396  1001450    Pfund
# 2         Albania     3029278    28748      Lek
# 3         Algeria    39542166  2381741    Dinar
# 4  American Samoa       54343      199   Dollar

# %%
# load world_gdp_2019.csv
world_gdp = pd.read_csv('world_gdp_2019.csv',sep=';')
world_gdp.head()
# Out:
#   Country Name Country Code       GDP_US$
# 0        Aruba          ABW           NaN
# 1  Afghanistan          AFG  1.929110e+10
# 2       Angola          AGO  8.941719e+10
# 3      Albania          ALB  1.528661e+10
# 4      Andorra          AND  3.155065e+09

# %% [markdown]
# **Q1.1** Using the dataframes created in Q1.0, answer the following.
#
# * a. Create a dataframe *cn_gdp* that shows the countries and their GDPs by joining the two dataframes above. Note that you need to show all the countries in *country* dataframe even if there is no information in *gdp* dataframe.
#
# * b. Remove the rows where the *GDP_US$* columns shows a *NaN* value.

# %%
# Q1.1 a
merged = pd.merge(countries, world_gdp,left_on='Country',right_on='Country Name',how="left")
cn_gdp = merged
cn_gdp[['Country','GDP_US$']]
# Out:
#                       Country       GDP_US$
# 0                 Afghanistan  1.929110e+10
# 1                       Egypt  3.030810e+11
# 2                     Albania  1.528661e+10
# 3                     Algeria  1.711580e+11
# 4              American Samoa  6.380000e+08
# ..                        ...           ...
# 241         Wallis and Futuna           NaN
# 242          Christmas Island           NaN
# 243            Western Sahara           NaN
# 244  Central African Republic  2.220307e+09
# 245                    Cyprus  2.494907e+10
#
# [246 rows x 2 columns]

# %%
# Q1.1 b

cn_gdp = cn_gdp.dropna()
cn_gdp[['Country','GDP_US$']]
# Out:
#                       Country       GDP_US$
# 0                 Afghanistan  1.929110e+10
# 1                       Egypt  3.030810e+11
# 2                     Albania  1.528661e+10
# 3                     Algeria  1.711580e+11
# 4              American Samoa  6.380000e+08
# ..                        ...           ...
# 238             United States  2.143320e+13
# 239            United Kingdom  2.830810e+12
# 240                   Vietnam  2.619210e+11
# 244  Central African Republic  2.220307e+09
# 245                    Cyprus  2.494907e+10
#
# [181 rows x 2 columns]

# %% [markdown]
# **Q2.1** Add a column *IncomeGroup* to the dataframe *cn_gdp* based on the  GDP of the country and  GDP ranges and the corresponding income group labels below.
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;}
# .tg th{font-family:Arial, sans-serif;font-size:14px;font-weight:normal;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;}
# .tg .tg-1wig{font-weight:bold;text-align:left;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
#   <tr>
#     <th class="tg-1wig" colspan="2"> GDP range</th>
#     <th class="tg-0lax" rowspan="2">Income group</th>
#   </tr>
#   <tr>
#     <td class="tg-1wig">Min GDP</td>
#     <td class="tg-1wig">Max GDP</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">0</td>
#     <td class="tg-0lax">5.0e+08</td>
#     <td class="tg-0lax">low</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">5.0e+08</td>
#     <td class="tg-0lax">5.0e+09</td>
#     <td class="tg-0lax">lower middle</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">5.0e+09</td>
#     <td class="tg-0lax">5.0e+10</td>
#     <td class="tg-0lax">middle</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">5.0e+10</td>
#     <td class="tg-0lax">5e+11</td>
#     <td class="tg-0lax">upper middle</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">5e+11</td>
#     <td class="tg-0lax">5.0e+13</td>
#     <td class="tg-0lax">high</td>
#   </tr>
# </table>

# %%
bin = [0,5.0e+08,5.0e+09,5.0e+10,5e+11,5.0e+13]
groups = ['low','lower middle', 'middle', 'upper middle', 'high']

cn_gdp['IncomeGroup'] = pd.cut(cn_gdp['GDP_US$'],bin,labels=groups)

cn_gdp[['Country','GDP_US$','IncomeGroup']]
# Out:
# /var/folders/1r/pgjdbkqx46qfv47dzjc8jy180000gn/T/ipykernel_78408/790381881.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                       Country       GDP_US$   IncomeGroup
# 0                 Afghanistan  1.929110e+10        middle
# 1                       Egypt  3.030810e+11  upper middle
# 2                     Albania  1.528661e+10        middle
# 3                     Algeria  1.711580e+11  upper middle
# 4              American Samoa  6.380000e+08  lower middle
# ..                        ...           ...           ...
# 238             United States  2.143320e+13          high
# 239            United Kingdom  2.830810e+12          high
# 240                   Vietnam  2.619210e+11  upper middle
# 244  Central African Republic  2.220307e+09  lower middle
# 245                    Cyprus  2.494907e+10        middle
#
# [181 rows x 3 columns]

# %% [markdown]
# **Q2.2**  Using the dataframe from above, group the countries by *IncomeGroup* column and show the average GDP for each income group.

# %%
grouped_cn_gdp = cn_gdp.groupby('IncomeGroup')[['GDP_US$','IncomeGroup']]
grouped_cn_gdp.mean()
# Out:
#                    GDP_US$
# IncomeGroup
# low           2.158974e+08
# lower middle  2.118833e+09
# middle        1.924676e+10
# upper middle  1.939990e+11
# high          3.084490e+12

# %% [markdown]
# **Q2.3**  Using the dataframe from Q2.1, group the countries by *IncomeGroup* column and plot a bar chart for the median GDP (GDP_US$) for each income group. The y-axis should be in log scale.

# %%
median = grouped_cn_gdp.median()
print(groups)
plt.bar(groups,median['GDP_US$'],log=True)
# Out:
# ['low', 'lower middle', 'middle', 'upper middle', 'high']
# <BarContainer object of 5 artists>

# %% [markdown]
# **Q3.0** Download the *capitals.csv*  and *major_cities.csv* files from D2L in the current folder. Load them into two dataframes and show first 5 rows. The major cities are some of the cities with relatively large population. The capitals are capitals of the countries.

# %%
# Load capitals.csv

capitals = pd.read_csv('capitals.csv',sep=',')
capitals.head()
# Out:
#    CapitalCity           Country CountryCode   Latitude   Longitude
# 0        Abuja           Nigeria          NG   9.057850    7.495080
# 1        Accra             Ghana          GH   5.556020   -0.196900
# 2    Adamstown  Pitcairn Islands          PN -25.066397 -130.100197
# 3  Addis Ababa          Ethiopia          ET   9.024970   38.746890
# 4      Algiers           Algeria          DZ  36.752500    3.041970

# %%
# Load major_cities.csv

major_cities = pd.read_csv('major_cities.csv',sep=',')
major_cities.head()
# Out:
#        City   Country  CityPopulation
# 0  Shanghai     China        22315500
# 1   Karachi  Pakistan        13052000
# 2    Mumbai     India        12691800
# 3   Beijing     China        11716600
# 4  Istanbul    Turkey        11174300

# %% [markdown]
# **Q3.1** For each country that has a Megacity (i.e. city with population more than 10 million), show the name of country and the number of Megacities it has. Note, the countries should be sorted in descending order based on the number of megacities they have.

# %%
Megacity = major_cities[major_cities['CityPopulation']>10e6]
Megacity[['Country','City']].groupby('Country').count().sort_values('City',ascending=False)
# Out:
#              City
# Country
# China           4
# India           2
# Brazil          1
# Nigeria         1
# Pakistan        1
# Russia          1
# South Korea     1
# Turkey          1

# %% [markdown]
# **Q3.2** For the countries each of whose capital is a major city, show the name of the top 7 capitals (ordered by thier capital city population) and the population of its capital, along with the correspinding country name.

# %%
capital_major_city = pd.merge(capitals,major_cities,left_on='CapitalCity',right_on='City').sort_values('CityPopulation',ascending=False)
capital_major_city = capital_major_city.rename(columns={'Country_x':'Country Name'})
capital_major_city[['CapitalCity','CityPopulation','Country Name']].head(7)
# Out:
#     CapitalCity  CityPopulation                      Country Name
# 62      Beijing        11716600                             China
# 59    New Delhi        10928000                             India
# 56       Moscow        10381200                            Russia
# 75        Seoul        10349300                       South Korea
# 33      Jakarta         9588200                         Indonesia
# 43     Kinshasa         9463800  Democratic Republic of the Congo
# 52  Mexico City         8851100                            Mexico

# %% [markdown]
# **Q4.0** For the questions Q4.1 and Q4.3, you will plot data on a map. If you have installed an Anaconda Python distribution in your local machine, you have to install basemap and plotly packages. If you are using FCS lab VM, then they are already installed in the VMs.

# %% [markdown]
# **Q4.1** From question Q3.2, plot the name of the top 7 capitals (i.e. by capital city population) in a map of the world.  Use the Basemap module for this.

# %%
capital_major_city
# Out:
#     CapitalCity           Country Name CountryCode  Latitude  Longitude  \
# 62      Beijing                  China          CN  39.90750  116.39723
# 59    New Delhi                  India          IN  28.63576   77.22445
# 56       Moscow                 Russia          RU  55.75222   37.61556
# 75        Seoul            South Korea          KR  37.56600  126.97840
# 33      Jakarta              Indonesia          ID  -6.21462  106.84513
# ..          ...                    ...         ...       ...        ...
# 17  Brazzaville  Republic of the Congo          CG  -4.26613   15.28318
# 35      Yerevan                Armenia          AM  40.18111   44.51361
# 57    N'Djamena                   Chad          TD  12.10672   15.04440
# 60  Ouagadougou           Burkina Faso          BF  12.36566   -1.53388
# 28       Dublin                Ireland          IE  53.33306   -6.24889
#
#            City              Country_y  CityPopulation
# 62      Beijing                  China        11716600
# 59    New Delhi                  India        10928000
# 56       Moscow                 Russia        10381200
# 75        Seoul            South Korea        10349300
# 33      Jakarta              Indonesia         9588200
# ..          ...                    ...             ...
# 17  Brazzaville  Republic of the Congo         1115800
# 35      Yerevan                Armenia         1093500
# 57    N'Djamena                   Chad         1092000
# 60  Ouagadougou           Burkina Faso         1086500
# 28       Dublin                Ireland         1024000
#
# [87 rows x 8 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap


city_name = capital_major_city['CapitalCity'].values[:7]
population = capital_major_city['CityPopulation'].values[:7]


lats = capital_major_city['Latitude'].values[:7]
lons = capital_major_city['Longitude'].values[:7]

fig = plt.gcf()
fig.set_size_inches(18, 12)

m = Basemap(projection='merc', 
            llcrnrlat=-80, urcrnrlat=80, 
            llcrnrlon=-180, urcrnrlon=180,
            lat_ts=20,
            resolution='c')

m.bluemarble(scale=0.2)
m.drawcoastlines(color='white', linewidth=0.2)

x, y = m(lons, lats)  # transform coordinates
plt.scatter(x, y, 30, marker='o', color='Red')
for i in range(7):
    plt.text(x=x[i]+0.01*x[i], y=y[i]+0.02*y[i], s=city_name[i], fontdict=dict(color='white',size=15))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Q4.2** Add a column *GDP_per_capita* to the dataframe *cn_gdp* in Q2.1 . This will be a calculated column based on the GDP per capita of each country.

# %%
cn_gdp['GDP_per_captia'] = (cn_gdp['GDP_US$']/cn_gdp['Population'])
cn_gdp
# Out:
# /var/folders/1r/pgjdbkqx46qfv47dzjc8jy180000gn/T/ipykernel_78408/4161150114.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                       Country  Population     Area Currency  \
# 0                 Afghanistan    32564342   652230  Afghani
# 1                       Egypt    88487396  1001450    Pfund
# 2                     Albania     3029278    28748      Lek
# 3                     Algeria    39542166  2381741    Dinar
# 4              American Samoa       54343      199   Dollar
# ..                        ...         ...      ...      ...
# 238             United States   321368864  9826675   Dollar
# 239            United Kingdom    64088222   243610    Pfund
# 240                   Vietnam    94348835   331210     Dong
# 244  Central African Republic     5391539   622984    Franc
# 245                    Cyprus     1189197     9251     Euro
#
#                  Country Name Country Code       GDP_US$   IncomeGroup  \
# 0                 Afghanistan          AFG  1.929110e+10        middle
# 1                       Egypt          EGY  3.030810e+11  upper middle
# 2                     Albania          ALB  1.528661e+10        middle
# 3                     Algeria          DZA  1.711580e+11  upper middle
# 4              American Samoa          ASM  6.380000e+08  lower middle
# ..                        ...          ...           ...           ...
# 238             United States          USA  2.143320e+13          high
# 239            United Kingdom          GBR  2.830810e+12          high
# 240                   Vietnam          VNM  2.619210e+11  upper middle
# 244  Central African Republic          CAF  2.220307e+09  lower middle
# 245                    Cyprus          CYP  2.494907e+10        middle
#
#      GDP_per_captia
# 0        592.399626
# 1       3425.131868
# 2       5046.289107
# 3       4328.493285
# 4      11740.242534
# ..              ...
# 238    66693.455406
# 239    44170.518570
# 240     2776.091512
# 244      411.813272
# 245    20979.757991
#
# [181 rows x 9 columns]

# %% [markdown]
# **Q4.3** Using the above dataframe, create a choropleth map of the world based on the GDP per capita of each country. Use the plotly module for this.

# %%
import pandas as pd
import plotly.express as px

cn_gdp['Country Code'] = merged['Country Code'].dropna()
fig = px.choropleth(cn_gdp, 
                    locations="Country Code",
                    color="GDP_per_captia", 
                    hover_name="Country",
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# /var/folders/1r/pgjdbkqx46qfv47dzjc8jy180000gn/T/ipykernel_78408/1089591096.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="e26d369a-eb57-4c40-b9e2-91c31c9e84af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e26d369a-eb57-4c40-b9e2-91c31c9e84af")) {                    Plotly.newPlot(                        "e26d369a-eb57-4c40-b9e2-91c31c9e84af",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Country Code=%{location}<br>GDP_per_captia=%{z}<extra></extra>","hovertext":["Afghanistan","Egypt","Albania","Algeria","American Samoa","Andorra","Angola","Antigua and Barbuda","Equatorial Guinea","Argentina","Armenia","Azerbaijan","Ethiopia","Australia","Bahamas","Bahrain","Bangladesh","Barbados","Belarus","Belgium","Belize","Benin","Bermuda","Bhutan","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","Bulgaria","Burkina Faso","Burundi","Chile","China","Costa Rica","Curacao","Denmark","Democratic Republic of the Congo","Germany","Dominica","Dominican Republic","Djibouti","Ecuador","El Salvador","Estonia","Faroe Islands","Fiji","Finland","France","Gabon","Georgia","Ghana","Grenada","Greece","Guam","Guatemala","Guinea","Guinea-Bissau","Guyana","Haiti","Honduras","India","Indonesia","Iraq","Iran","Ireland","Iceland","Israel","Italy","Jamaica","Japan","Jordan","Cayman Islands","Cambodia","Cameroon","Canada","Kazakhstan","Qatar","Kenya","Kiribati","Colombia","Comoros","Republic of the Congo","Kosovo","Croatia","Cuba","Kuwait","Lesotho","Latvia","Lebanon","Liberia","Libya","Lithuania","Luxembourg","Madagascar","Malawi","Malaysia","Maldives","Mali","Malta","Morocco","Marshall Islands","Mauritania","Mauritius","Mexico","Moldova","Monaco","Mongolia","Montenegro","Mozambique","Namibia","Nauru","Nepal","New Zealand","Nicaragua","Netherlands","Niger","Nigeria","Northern Mariana Islands","Norway","Oman","Austria","Timor-Leste","Pakistan","Palau","Panama","Papua New Guinea","Paraguay","Peru","Philippines","Poland","Portugal","Puerto Rico","Rwanda","Romania","Russia","Solomon Islands","Zambia","Samoa","San Marino","Sao Tome and Principe","Saudi Arabia","Sweden","Switzerland","Senegal","Serbia","Seychelles","Sierra Leone","Zimbabwe","Singapore","Slovenia","Somalia","Spain","Sri Lanka","South Africa","Sudan","Suriname","Tajikistan","Tanzania","Thailand","Togo","Tonga","Trinidad and Tobago","Chad","Czech Republic","Tunisia","Turkey","Turkmenistan","Turks and Caicos Islands","Tuvalu","Uganda","Ukraine","Hungary","Uruguay","Uzbekistan","Vanuatu","United Arab Emirates","United States","United Kingdom","Vietnam","Central African Republic","Cyprus"],"locations":["AFG","EGY","ALB","DZA","ASM","AND","AGO","ATG","GNQ","ARG","ARM","AZE","ETH","AUS","BHS","BHR","BGD","BRB","BLR","BEL","BLZ","BEN","BMU","BTN","BOL","BIH","BWA","BRA","BGR","BFA","BDI","CHL","CHN","CRI","CUW","DNK","COD","DEU","DMA","DOM","DJI","ECU","SLV","EST","FRO","FJI","FIN","FRA","GAB","GEO","GHA","GRD","GRC","GUM","GTM","GIN","GNB","GUY","HTI","HND","IND","IDN","IRQ","IRN","IRL","ISL","ISR","ITA","JAM","JPN","JOR","CYM","KHM","CMR","CAN","KAZ","QAT","KEN","KIR","COL","COM","COG","XKX","HRV","CUB","KWT","LSO","LVA","LBN","LBR","LBY","LTU","LUX","MDG","MWI","MYS","MDV","MLI","MLT","MAR","MHL","MRT","MUS","MEX","MDA","MCO","MNG","MNE","MOZ","NAM","NRU","NPL","NZL","NIC","NLD","NER","NGA","MNP","NOR","OMN","AUT","TLS","PAK","PLW","PAN","PNG","PRY","PER","PHL","POL","PRT","PRI","RWA","ROU","RUS","SLB","ZMB","WSM","SMR","STP","SAU","SWE","CHE","SEN","SRB","SYC","SLE","ZWE","SGP","SVN","SOM","ESP","LKA","ZAF","SDN","SUR","TJK","TZA","THA","TGO","TON","TTO","TCD","CZE","TUN","TUR","TKM","TCA","TUV","UGA","UKR","HUN","URY","UZB","VUT","ARE","USA","GBR","VNM","CAF","CYP"],"name":"","type":"choropleth","z":[592.3996255781861,3425.1318684979724,5046.289106843281,4328.493284864567,11740.2425 ...
